# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
from skyfield import api
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ts = api.load.timescale()

# %%
ts.tt(1991.25).tt_calendar()
# Out:
# (1991, 4, 2, 0, 0, 0.0)

# %%
t = ts.utc(1976, np.arange((2018 - 1976) * 12))
print(t)
print(t[0].utc_jpl())
print(t[-1].utc_jpl())

# We want this graph to look like the one at:
# https://en.wikipedia.org/wiki/DUT1
print(api.__file__)
plot(t.J, t.dut1)
# Out:
# <Time 504 values from tt=2442747.500535 to tt=2458130.500801>
# A.D. 1975-Dec-01 00:00:00.0000 UT
# A.D. 2018-Jan-12 00:00:00.0000 UT
# /home/brandon/src/skyfield/skyfield/api.py
