# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
transactions_text = """\
trip,category,amount
Boston,Airfare,560
Boston,Meals,25
Boston,Meals,35
Boston,Meals,20
Boston,Hotel,450
New York,Airfare,670
Atlanta,Airfare,340
New York,Meals,60
New York,Meals,55
New York,Hotel,250
Atlanta,Meals,34
Atlanta,Meals,22
Atlanta,Meals,51
"""

# %%
from StringIO import StringIO
df = pd.read_csv(StringIO(transactions_text))

# %%
df.head()
# Out:
#      trip category  amount
# 0  Boston  Airfare     560
# 1  Boston    Meals      25
# 2  Boston    Meals      35
# 3  Boston    Meals      20
# 4  Boston    Hotel     450

# %%
df.groupby(['trip']).head()
# Out:
#                  trip category  amount
# trip
# Atlanta  6    Atlanta  Airfare     340
#          10   Atlanta    Meals      34
#          11   Atlanta    Meals      22
#          12   Atlanta    Meals      51
# Boston   0     Boston  Airfare     560
#          1     Boston    Meals      25
#          2     Boston    Meals      35
#          3     Boston    Meals      20
#          4     Boston    Hotel     450
# New York 5   New York  Airfare     670
#          7   New York    Meals      60
#          8   New York    Meals      55
#          9   New York    Hotel     250

# %%
df.groupby(['trip']).sum()
# Out:
#           amount
# trip
# Atlanta      447
# Boston      1090
# New York    1035

# %%
df.groupby(['category']).sum()
# Out:
#           amount
# category
# Airfare     1570
# Hotel        700
# Meals        302

# %%
grid = df.groupby(['trip', 'category']
                ).sum().unstack('category').fillna(0)
grid['Totals'] = df.groupby(['trip']).sum()

# %%
grid
# Out:
#            amount                Totals
# category  Airfare  Hotel  Meals
# trip
# Atlanta       340      0    107     447
# Boston        560    450     80    1090
# New York      670    250    115    1035
