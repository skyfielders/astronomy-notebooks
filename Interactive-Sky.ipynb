# %% [markdown]
# # Simple star field
#
# Moving your mouse pointer across the display below
# will rotate the celestial sphere,
# showing the brightest stars down to magnitude 5.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib.downloader import download_all
download_all()
# Out:
# Getting data file ftp://cdsarc.u-strasbg.fr/pub/cats/I/239/hip_main.dat.gz...
# Getting data file ftp://cdsarc.u-strasbg.fr/pub/cats/VI/42/data.dat...
# Getting data file http://ssd.jpl.nasa.gov/dat/ELEMENTS.COMET...
# Getting data file http://ssd.jpl.nasa.gov/dat/ELEMENTS.NUMBR.gz...
# Getting data file http://ssd.jpl.nasa.gov/dat/ELEMENTS.UNNUM.gz...
# Getting data file http://www.celestrak.com/NORAD/elements/visual.txt...
# Getting data file http://www.pbarbier.com/constellations/bound_verts_18.txt...
# Getting data file https://raw.github.com/astronexus/HYG-Database/master/hygfull.csv...
# Done!

# %%
from lib import sky
sky.starfield()
# Out:
# <style>
#   .constellation {fill: #dddddd}
#   .star-red {fill: #BC243C}
#   .star-blue {fill: #002664}
# </style>
# <script>
# ...
